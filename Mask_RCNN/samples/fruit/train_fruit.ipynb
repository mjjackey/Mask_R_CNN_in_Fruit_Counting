# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !pwd
# !ls -al
# Out:
# /content
# total 20
# drwxr-xr-x 1 root root 4096 Jul 29 09:47 .
# drwxr-xr-x 1 root root 4096 Jul 29 07:11 ..
# drwxr-xr-x 1 root root 4096 Jul 19 16:14 .config
# drwx------ 3 root root 4096 Jul 29 09:47 drive
# drwxr-xr-x 1 root root 4096 Jul 19 16:14 sample_data

# %%
import os
os.chdir("drive/My Drive/Mask_RCNN")

# %%
# !ls
# Out:
# assets	  images       mask_rcnn_coco.h5   requirements.txt	    setup.py
# build	  LICENSE      mask_rcnn.egg-info  run_bash_mask_cnn.ipynb
# datasets  logs	       mrcnn		   samples
# dist	  MANIFEST.in  README.md	   setup.cfg

# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Root directory of the project
# ROOT_DIR = os.path.abspath("../../")
ROOT_DIR = os.path.abspath("./")  # currnet directory
print(ROOT_DIR)

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn.config import Config
from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log

# %matplotlib inline 

# directory of dataset 
DATASET_DIR = os.path.join(ROOT_DIR,"datasets/apples")
print(DATASET_DIR)

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
# Out:
# /content/drive/My Drive/Mask_RCNN
# /content/drive/My Drive/Mask_RCNN/datasets/apples
# Using TensorFlow backend.

# %% [markdown]
# # Train

# %% [markdown]
# ## Configurations

# %%
class FruitConfig(Config):
    """Configuration for training on the fruit dataset.
    Derives from the base Config class and overrides some values.
    """
    # Give the configuration a recognizable name
    NAME = "apple"

    # We use a GPU with 12GB memory, which can fit two images.
    # Adjust down if you use a smaller GPU.
    IMAGES_PER_GPU = 1   ####

    # Number of classes (including background)
    NUM_CLASSES = 1 + 1  # Background + fruit

    # Number of training steps per epoch
    STEPS_PER_EPOCH = 100

    # Skip detections with < 90% confidence
    DETECTION_MIN_CONFIDENCE = 0.9

config = FruitConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           apple
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %% [markdown]
# ## Dataset
# override the following methods:
# * load_fruit()
# * load_mask()
# * image_reference()

# %%
import csv
import skimage.draw

class FruitDataset(utils.Dataset):
      def load_fruit(self, dataset_dir, subset):
          """Load a subset of the fruit dataset.
          dataset_dir: Root directory of the dataset.
          subset: Subset to load: train,val or test
          """
          # Add classes. We have only one class to add.
          self.add_class("apple", 1, "apple")

          # Train, validation or test dataset?
          assert subset in ["train", "val","test"]
          dataset_dir = os.path.join(dataset_dir, subset)
          print(dataset_dir)
          
          # Load annotations
          img_file_list=[]
          ano_file_list=[]
          for name in os.listdir(dataset_dir):
              if name.endswith(".png"):
                 img_file_list.append(name)
              elif name.endswith(".csv"):
                 ano_file_list.append(name)
          
       
          for name in img_file_list:
              index_=name.index("_")
              pre_name=name[:index_+3].strip()
#               print(pre_name)

#               try:
#                  ano_index=ano_file_list.index(pre_name)
#               except:
#                  continue
              
              if (pre_name+".csv") not in ano_file_list:
                  continue
                
              r_list=[]
              c_list=[]
              radius_list=[]
              ano_path=os.path.join(dataset_dir, pre_name+".csv")
              with open(ano_path) as f:  ####
                  f_csv=csv.reader(f)
                  headers=next(f_csv)
                  for row in f_csv:
                      r_list.append(row[2])  ##### subscript, row is y, column is x
                      c_list.append(row[1])
                      radius_list.append(row[3])
              
#               print("r_list:",r_list)
#               print("c_list:",c_list)
#               print("radius_list:",radius_list)
              
              image_path = os.path.join(dataset_dir, name)
              image = skimage.io.imread(image_path)
              height, width = image.shape[:2] 
#               print("height:",height,"width:",width)   # 202*308
              
              self.add_image(
                  "apple",
                  image_id=name,  # use file name as a unique image id
                  path=image_path,
                  width=width, height=height,
                  r=r_list,
                  c=c_list,
                  radius=radius_list)  ######
             
       
      def load_mask(self, image_id):
          """Generate instance masks for an image.
             Returns:
             masks: A bool array of shape [height, width, instance count] with
                one mask per instance.
             class_ids: a 1D array of class IDs of the instance masks.
          """
          # If not a balloon dataset image, delegate to parent class.
          image_info = self.image_info[image_id]
          if image_info["source"] != "apple":
              return super(self.__class__, self).load_mask(image_id)

          # Convert circles to a bitmap mask of shape
          # [height, width, instance_count]
          info = self.image_info[image_id]
#           print("len(r):",len(info["r"]))
#           print(info["r"])
#           print(info["c"])
#           print(info["radius"])
          mask = np.zeros([info["height"], info["width"], len(info["r"])],
                          dtype=np.uint8)
#           print("mask_shape:",mask.shape)
#           index=0
          for index in range(len(info["r"])):
              # Get indexes of pixels inside the circle and set them to 1
#               print("r:",info["r"][index])
#               print("c:",info["c"][index])
#               print("radius:",info["radius"][index])
              rr, cc = skimage.draw.circle(float(info["r"][index]), float(info["c"][index]), float(info["radius"][index]),mask.shape)  
              mask[rr, cc, index] = 1

          # Return mask, and array of class IDs of each instance. Since we have
          # one class ID only, we return an array of 1s
          return mask.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32)
          
      
      def image_reference(self, image_id):
          """Return the path of the image."""
          info = self.image_info[image_id]
          if info["source"] == "apple":
              return info["path"]
          else:
              super(self.__class__, self).image_reference(image_id)

# %%
# Load Training dataset.
dataset_train = FruitDataset()
dataset_train.load_fruit(DATASET_DIR, "train")

dataset_train.prepare()

print("Images: {}\nClasses: {}".format(len(dataset_train.image_ids), dataset_train.class_names))
# Out:
# /content/drive/My Drive/Mask_RCNN/datasets/apples/train
# Images: 896
# Classes: ['BG', 'apple']

# %%
### Load validation dataset
dataset_val = FruitDataset()
dataset_val.load_fruit(DATASET_DIR, "val")

# Must call before using the dataset
dataset_val.prepare()

print("Images: {}\nClasses: {}".format(len(dataset_val.image_ids), dataset_val.class_names))
# Out:
# /content/drive/My Drive/Mask_RCNN/datasets/apples/val
# Images: 112
# Classes: ['BG', 'apple']

# %% [markdown]
# ## Create Training Model

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0729 09:50:08.097356 140428436277120 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0729 09:50:08.160041 140428436277120 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0729 09:50:08.201582 140428436277120 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0729 09:50:08.256105 140428436277120 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1919: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0729 09:50:08.260562 140428436277120 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0729 09:50:11.406968 140428436277120 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# W0729 09:50:12.112375 140428436277120 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/array_ops.py:1354: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0729 09:50:12.273129 140428436277120 deprecation_wrapper.py:119] From /content/drive/My Drive/Mask_RCNN/mrcnn/model.py:553: The name tf.random_shuffle is deprecated. Please use tf.random.shuffle instead.
#
# W0729 09:50:12.560604 140428436277120 deprecation_wrapper.py:119] From /content/drive/My Drive/Mask_RCNN/mrcnn/utils.py:202: The name tf.log is deprecated. Please use tf.math.log instead.
#
# W0729 09:50:12.588860 140428436277120 deprecation.py:506] From /content/drive/My Drive/Mask_RCNN/mrcnn/model.py:600: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead

# %%
# Load weights trained on MS COCO, but skip layers that
# are different due to the different number of classes
# See README for instructions to download the COCO weights
model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])

# %% [markdown]
# ## Training

# %%
########Transfer learning 
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. We can also pass a regular expression to select
# which layers to train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE, 
            epochs=5, 
            layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /content/drive/My Drive/Mask_RCNN/logs/apple20190728T1742/mask_rcnn_apple_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# W0728 17:43:25.796282 140644080289664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/gradients_util.py:93: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# /usr/local/lib/python3.6/dist-packages/keras/engine/training_generator.py:47: UserWarning: Using a generator with `use_multiprocessing=True` and multiple workers may duplicate your data. Please consider using the`keras.utils.Sequence class.
#   UserWarning('Using a generator with `use_multiprocessing=True`'
# W0728 17:43:31.170936 140644080289664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:850: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# W0728 17:43:31.172505 140644080289664 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:853: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
# Epoch 1/5
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 11)
# mask_shape: (202, 308, 11)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 12)
# mask_shape: (202, 308, 12)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 11)
# mask_shape: (202, 308, 11)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 11)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 11)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 15)
# mask_shape: (202, 308, 15)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 11)
# mask_shape: (202, 308, 11)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 11)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 11)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 14)
# mask_shape: (202, 308, 14)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 14)
# mask_shape: (202, 308, 14)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 12)
# mask_shape: (202, 308, 12)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 13)
# mask_shape: (202, 308, 13)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 8)
#   1/100 [..............................] - ETA: 3:21:24 - loss: 2.2602 - rpn_class_loss: 0.1964 - rpn_bbox_loss: 0.2121 - mrcnn_class_loss: 0.1868 - mrcnn_bbox_loss: 0.8588 - mrcnn_mask_loss: 0.8061mask_shape: (202, 308, 7)
#   2/100 [..............................] - ETA: 2:21:07 - loss: 2.1598 - rpn_class_loss: 0.1903 - rpn_bbox_loss: 0.2118 - mrcnn_class_loss: 0.1840 - mrcnn_bbox_loss: 0.7732 - mrcnn_mask_loss: 0.8006mask_shape: (202, 308, 7)
#   3/100 [..............................] - ETA: 2:00:24 - loss: 2.4725 - rpn_class_loss: 0.1735 - rpn_bbox_loss: 0.4392 - mrcnn_class_loss: 0.2390 - mrcnn_bbox_loss: 0.7670 - mrcnn_mask_loss: 0.8538mask_shape: (202, 308, 5)
#   4/100 [>.............................] - ETA: 1:49:43 - loss: 2.5440 - rpn_class_loss: 0.1602 - rpn_bbox_loss: 0.5203 - mrcnn_class_loss: 0.2604 - mrcnn_bbox_loss: 0.7293 - mrcnn_mask_loss: 0.8738mask_shape: (202, 308, 5)
#   5/100 [>.............................] - ETA: 1:42:46 - loss: 2.6129 - rpn_class_loss: 0.1292 - rpn_bbox_loss: 0.5022 - mrcnn_class_loss: 0.2701 - mrcnn_bbox_loss: 0.7266 - mrcnn_mask_loss: 0.9848mask_shape: (202, 308, 5)
#   6/100 [>.............................] - ETA: 1:37:52 - loss: 2.6233 - rpn_class_loss: 0.1084 - rpn_bbox_loss: 0.4836 - mrcnn_class_loss: 0.2702 - mrcnn_bbox_loss: 0.7216 - mrcnn_mask_loss: 1.0394mask_shape: (202, 308, 5)
#   7/100 [=>............................] - ETA: 1:34:07 - loss: 2.5551 - rpn_class_loss: 0.1005 - rpn_bbox_loss: 0.4338 - mrcnn_class_loss: 0.2735 - mrcnn_bbox_loss: 0.7404 - mrcnn_mask_loss: 1.0069mask_shape: (202, 308, 2)
#   8/100 [=>............................] - ETA: 1:31:15 - loss: 2.4881 - rpn_class_loss: 0.0939 - rpn_bbox_loss: 0.3957 - mrcnn_class_loss: 0.2713 - mrcnn_bbox_loss: 0.7477 - mrcnn_mask_loss: 0.9796mask_shape: (202, 308, 2)
#   9/100 [=>............................] - ETA: 1:28:42 - loss: 2.4493 - rpn_class_loss: 0.0854 - rpn_bbox_loss: 0.3990 - mrcnn_class_loss: 0.2461 - mrcnn_bbox_loss: 0.7697 - mrcnn_mask_loss: 0.9490mask_shape: (202, 308, 7)
#  10/100 [==>...........................] - ETA: 1:26:32 - loss: 2.3940 - rpn_class_loss: 0.0786 - rpn_bbox_loss: 0.3984 - mrcnn_class_loss: 0.2277 - mrcnn_bbox_loss: 0.7688 - mrcnn_mask_loss: 0.9205mask_shape: (202, 308, 7)
#  11/100 [==>...........................] - ETA: 1:24:36 - loss: 2.5760 - rpn_class_loss: 0.1119 - rpn_bbox_loss: 0.5278 - mrcnn_class_loss: 0.2369 - mrcnn_bbox_loss: 0.7948 - mrcnn_mask_loss: 0.9046mask_shape: (202, 308, 11)
#  12/100 [==>...........................] - ETA: 1:22:50 - loss: 2.7119 - rpn_class_loss: 0.1362 - rpn_bbox_loss: 0.6257 - mrcnn_class_loss: 0.2472 - mrcnn_bbox_loss: 0.8120 - mrcnn_mask_loss: 0.8909mask_shape: (202, 308, 11)
#  13/100 [==>...........................] - ETA: 1:21:14 - loss: 2.6440 - rpn_class_loss: 0.1287 - rpn_bbox_loss: 0.5897 - mrcnn_class_loss: 0.2576 - mrcnn_bbox_loss: 0.7896 - mrcnn_mask_loss: 0.8784mask_shape: (202, 308, 5)
#  14/100 [===>..........................] - ETA: 1:19:43 - loss: 2.5720 - rpn_class_loss: 0.1220 - rpn_bbox_loss: 0.5579 - mrcnn_class_loss: 0.2599 - mrcnn_bbox_loss: 0.7671 - mrcnn_mask_loss: 0.8651mask_shape: (202, 308, 5)
#  15/100 [===>..........................] - ETA: 1:18:18 - loss: 2.5696 - rpn_class_loss: 0.1290 - rpn_bbox_loss: 0.5616 - mrcnn_class_loss: 0.2749 - mrcnn_bbox_loss: 0.7555 - mrcnn_mask_loss: 0.8487mask_shape: (202, 308, 2)
#  16/100 [===>..........................] - ETA: 1:17:00 - loss: 2.5470 - rpn_class_loss: 0.1314 - rpn_bbox_loss: 0.5578 - mrcnn_class_loss: 0.2846 - mrcnn_bbox_loss: 0.7411 - mrcnn_mask_loss: 0.8322mask_shape: (202, 308, 2)
#  17/100 [====>.........................] - ETA: 1:15:41 - loss: 2.4927 - rpn_class_loss: 0.1251 - rpn_bbox_loss: 0.5315 - mrcnn_class_loss: 0.2891 - mrcnn_bbox_loss: 0.7297 - mrcnn_mask_loss: 0.8173mask_shape: (202, 308, 5)
#  18/100 [====>.........................] - ETA: 1:14:28 - loss: 2.4387 - rpn_class_loss: 0.1199 - rpn_bbox_loss: 0.5083 - mrcnn_class_loss: 0.2933 - mrcnn_bbox_loss: 0.7145 - mrcnn_mask_loss: 0.8026mask_shape: (202, 308, 5)
#  19/100 [====>.........................] - ETA: 1:13:16 - loss: 2.4039 - rpn_class_loss: 0.1157 - rpn_bbox_loss: 0.5144 - mrcnn_class_loss: 0.2800 - mrcnn_bbox_loss: 0.7048 - mrcnn_mask_loss: 0.7890mask_shape: (202, 308, 7)
#  20/100 [=====>........................] - ETA: 1:12:07 - loss: 2.3683 - rpn_class_loss: 0.1121 - rpn_bbox_loss: 0.5188 - mrcnn_class_loss: 0.2676 - mrcnn_bbox_loss: 0.6941 - mrcnn_mask_loss: 0.7757mask_shape: (202, 308, 7)
#  21/100 [=====>........................] - ETA: 1:11:00 - loss: 2.3585 - rpn_class_loss: 0.1090 - rpn_bbox_loss: 0.5167 - mrcnn_class_loss: 0.2694 - mrcnn_bbox_loss: 0.7022 - mrcnn_mask_loss: 0.7611mask_shape: (202, 308, 5)
#  22/100 [=====>........................] - ETA: 1:09:54 - loss: 2.3379 - rpn_class_loss: 0.1063 - rpn_bbox_loss: 0.5127 - mrcnn_class_loss: 0.2683 - mrcnn_bbox_loss: 0.7033 - mrcnn_mask_loss: 0.7474mask_shape: (202, 308, 5)
#  23/100 [=====>........................] - ETA: 1:08:49 - loss: 2.2864 - rpn_class_loss: 0.1057 - rpn_bbox_loss: 0.4957 - mrcnn_class_loss: 0.2590 - mrcnn_bbox_loss: 0.6907 - mrcnn_mask_loss: 0.7353mask_shape: (202, 308, 11)
#  24/100 [======>.......................] - ETA: 1:07:46 - loss: 2.2365 - rpn_class_loss: 0.1051 - rpn_bbox_loss: 0.4793 - mrcnn_class_loss: 0.2508 - mrcnn_bbox_loss: 0.6777 - mrcnn_mask_loss: 0.7236mask_shape: (202, 308, 11)
#  25/100 [======>.......................] - ETA: 1:06:44 - loss: 2.1920 - rpn_class_loss: 0.1039 - rpn_bbox_loss: 0.4634 - mrcnn_class_loss: 0.2434 - mrcnn_bbox_loss: 0.6660 - mrcnn_mask_loss: 0.7154mask_shape: (202, 308, 3)
#  26/100 [======>.......................] - ETA: 1:05:42 - loss: 2.1475 - rpn_class_loss: 0.1026 - rpn_bbox_loss: 0.4490 - mrcnn_class_loss: 0.2360 - mrcnn_bbox_loss: 0.6525 - mrcnn_mask_loss: 0.7074mask_shape: (202, 308, 3)
#  27/100 [=======>......................] - ETA: 1:04:41 - loss: 2.1210 - rpn_class_loss: 0.1008 - rpn_bbox_loss: 0.4371 - mrcnn_class_loss: 0.2408 - mrcnn_bbox_loss: 0.6428 - mrcnn_mask_loss: 0.6996mask_shape: (202, 308, 5)
#  28/100 [=======>......................] - ETA: 1:03:41 - loss: 2.0924 - rpn_class_loss: 0.0990 - rpn_bbox_loss: 0.4261 - mrcnn_class_loss: 0.2416 - mrcnn_bbox_loss: 0.6336 - mrcnn_mask_loss: 0.6921mask_shape: (202, 308, 5)
#  29/100 [=======>......................] - ETA: 1:02:41 - loss: 2.0698 - rpn_class_loss: 0.0965 - rpn_bbox_loss: 0.4170 - mrcnn_class_loss: 0.2445 - mrcnn_bbox_loss: 0.6268 - mrcnn_mask_loss: 0.6851mask_shape: (202, 308, 5)
#  30/100 [========>.....................] - ETA: 1:01:42 - loss: 2.0456 - rpn_class_loss: 0.0940 - rpn_bbox_loss: 0.4083 - mrcnn_class_loss: 0.2458 - mrcnn_bbox_loss: 0.6193 - mrcnn_mask_loss: 0.6782mask_shape: (202, 308, 5)
#  31/100 [========>.....................] - ETA: 1:00:42 - loss: 2.0164 - rpn_class_loss: 0.0917 - rpn_bbox_loss: 0.4002 - mrcnn_class_loss: 0.2403 - mrcnn_bbox_loss: 0.6116 - mrcnn_mask_loss: 0.6726mask_shape: (202, 308, 2)
#  32/100 [========>.....................] - ETA: 59:44 - loss: 1.9859 - rpn_class_loss: 0.0895 - rpn_bbox_loss: 0.3921 - mrcnn_class_loss: 0.2354 - mrcnn_bbox_loss: 0.6017 - mrcnn_mask_loss: 0.6673  mask_shape: (202, 308, 2)
#  33/100 [========>.....................] - ETA: 58:47 - loss: 1.9888 - rpn_class_loss: 0.0889 - rpn_bbox_loss: 0.3920 - mrcnn_class_loss: 0.2477 - mrcnn_bbox_loss: 0.5981 - mrcnn_mask_loss: 0.6621mask_shape: (202, 308, 2)
#  34/100 [=========>....................] - ETA: 57:50 - loss: 1.9919 - rpn_class_loss: 0.0885 - rpn_bbox_loss: 0.3914 - mrcnn_class_loss: 0.2603 - mrcnn_bbox_loss: 0.5945 - mrcnn_mask_loss: 0.6572mask_shape: (202, 308, 2)
#  35/100 [=========>....................] - ETA: 56:53 - loss: 1.9787 - rpn_class_loss: 0.0867 - rpn_bbox_loss: 0.3858 - mrcnn_class_loss: 0.2633 - mrcnn_bbox_loss: 0.5921 - mrcnn_mask_loss: 0.6509mask_shape: (202, 308, 3)
#  36/100 [=========>....................] - ETA: 55:57 - loss: 1.9644 - rpn_class_loss: 0.0849 - rpn_bbox_loss: 0.3806 - mrcnn_class_loss: 0.2656 - mrcnn_bbox_loss: 0.5882 - mrcnn_mask_loss: 0.6450mask_shape: (202, 308, 3)
#  37/100 [==========>...................] - ETA: 55:01 - loss: 1.9449 - rpn_class_loss: 0.0833 - rpn_bbox_loss: 0.3724 - mrcnn_class_loss: 0.2664 - mrcnn_bbox_loss: 0.5816 - mrcnn_mask_loss: 0.6412mask_shape: (202, 308, 1)
#  38/100 [==========>...................] - ETA: 54:05 - loss: 1.9250 - rpn_class_loss: 0.0818 - rpn_bbox_loss: 0.3645 - mrcnn_class_loss: 0.2662 - mrcnn_bbox_loss: 0.5757 - mrcnn_mask_loss: 0.6367mask_shape: (202, 308, 1)
#  39/100 [==========>...................] - ETA: 53:10 - loss: 1.9147 - rpn_class_loss: 0.0803 - rpn_bbox_loss: 0.3615 - mrcnn_class_loss: 0.2676 - mrcnn_bbox_loss: 0.5740 - mrcnn_mask_loss: 0.6313mask_shape: (202, 308, 1)
#  40/100 [===========>..................] - ETA: 52:14 - loss: 1.9029 - rpn_class_loss: 0.0788 - rpn_bbox_loss: 0.3581 - mrcnn_class_loss: 0.2688 - mrcnn_bbox_loss: 0.5712 - mrcnn_mask_loss: 0.6261mask_shape: (202, 308, 1)
#  41/100 [===========>..................] - ETA: 51:19 - loss: 1.8913 - rpn_class_loss: 0.0782 - rpn_bbox_loss: 0.3541 - mrcnn_class_loss: 0.2646 - mrcnn_bbox_loss: 0.5718 - mrcnn_mask_loss: 0.6227mask_shape: (202, 308, 4)
#  42/100 [===========>..................] - ETA: 50:24 - loss: 1.8796 - rpn_class_loss: 0.0775 - rpn_bbox_loss: 0.3502 - mrcnn_class_loss: 0.2607 - mrcnn_bbox_loss: 0.5717 - mrcnn_mask_loss: 0.6195mask_shape: (202, 308, 4)
#  43/100 [===========>..................] - ETA: 49:29 - loss: 1.8685 - rpn_class_loss: 0.0768 - rpn_bbox_loss: 0.3466 - mrcnn_class_loss: 0.2620 - mrcnn_bbox_loss: 0.5684 - mrcnn_mask_loss: 0.6146mask_shape: (202, 308, 2)
#  44/100 [============>.................] - ETA: 48:36 - loss: 1.8533 - rpn_class_loss: 0.0761 - rpn_bbox_loss: 0.3430 - mrcnn_class_loss: 0.2605 - mrcnn_bbox_loss: 0.5640 - mrcnn_mask_loss: 0.6098mask_shape: (202, 308, 2)
#  45/100 [============>.................] - ETA: 47:41 - loss: 1.8343 - rpn_class_loss: 0.0752 - rpn_bbox_loss: 0.3375 - mrcnn_class_loss: 0.2562 - mrcnn_bbox_loss: 0.5590 - mrcnn_mask_loss: 0.6065mask_shape: (202, 308, 4)
#  46/100 [============>.................] - ETA: 46:48 - loss: 1.8147 - rpn_class_loss: 0.0743 - rpn_bbox_loss: 0.3322 - mrcnn_class_loss: 0.2523 - mrcnn_bbox_loss: 0.5527 - mrcnn_mask_loss: 0.6032mask_shape: (202, 308, 4)
#  47/100 [=============>................] - ETA: 45:55 - loss: 1.8036 - rpn_class_loss: 0.0736 - rpn_bbox_loss: 0.3291 - mrcnn_class_loss: 0.2516 - mrcnn_bbox_loss: 0.5500 - mrcnn_mask_loss: 0.5994mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 5)
#  48/100 [=============>................] - ETA: 45:01 - loss: 1.7925 - rpn_class_loss: 0.0729 - rpn_bbox_loss: 0.3258 - mrcnn_class_loss: 0.2511 - mrcnn_bbox_loss: 0.5468 - mrcnn_mask_loss: 0.5959mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 5)
#  49/100 [=============>................] - ETA: 44:07 - loss: 1.7832 - rpn_class_loss: 0.0726 - rpn_bbox_loss: 0.3309 - mrcnn_class_loss: 0.2468 - mrcnn_bbox_loss: 0.5415 - mrcnn_mask_loss: 0.5914mask_shape: (202, 308, 5)
#  50/100 [==============>...............] - ETA: 43:14 - loss: 1.7714 - rpn_class_loss: 0.0723 - rpn_bbox_loss: 0.3348 - mrcnn_class_loss: 0.2427 - mrcnn_bbox_loss: 0.5343 - mrcnn_mask_loss: 0.5871mask_shape: (202, 308, 5)
#  51/100 [==============>...............] - ETA: 42:21 - loss: 1.7638 - rpn_class_loss: 0.0713 - rpn_bbox_loss: 0.3303 - mrcnn_class_loss: 0.2458 - mrcnn_bbox_loss: 0.5324 - mrcnn_mask_loss: 0.5840mask_shape: (202, 308, 5)
#  52/100 [==============>...............] - ETA: 41:27 - loss: 1.7564 - rpn_class_loss: 0.0703 - rpn_bbox_loss: 0.3259 - mrcnn_class_loss: 0.2481 - mrcnn_bbox_loss: 0.5312 - mrcnn_mask_loss: 0.5809mask_shape: (202, 308, 5)
#  53/100 [==============>...............] - ETA: 40:34 - loss: 1.7519 - rpn_class_loss: 0.0694 - rpn_bbox_loss: 0.3248 - mrcnn_class_loss: 0.2500 - mrcnn_bbox_loss: 0.5295 - mrcnn_mask_loss: 0.5782mask_shape: (202, 308, 10)
#  54/100 [===============>..............] - ETA: 39:41 - loss: 1.7452 - rpn_class_loss: 0.0686 - rpn_bbox_loss: 0.3236 - mrcnn_class_loss: 0.2511 - mrcnn_bbox_loss: 0.5264 - mrcnn_mask_loss: 0.5756mask_shape: (202, 308, 10)
#  55/100 [===============>..............] - ETA: 38:48 - loss: 1.7736 - rpn_class_loss: 0.0690 - rpn_bbox_loss: 0.3449 - mrcnn_class_loss: 0.2467 - mrcnn_bbox_loss: 0.5385 - mrcnn_mask_loss: 0.5744mask_shape: (202, 308, 2)
#  56/100 [===============>..............] - ETA: 37:55 - loss: 1.7925 - rpn_class_loss: 0.0695 - rpn_bbox_loss: 0.3614 - mrcnn_class_loss: 0.2424 - mrcnn_bbox_loss: 0.5461 - mrcnn_mask_loss: 0.5731mask_shape: (202, 308, 2)
#  57/100 [================>.............] - ETA: 37:02 - loss: 1.7847 - rpn_class_loss: 0.0687 - rpn_bbox_loss: 0.3580 - mrcnn_class_loss: 0.2409 - mrcnn_bbox_loss: 0.5459 - mrcnn_mask_loss: 0.5712mask_shape: (202, 308, 5)
#  58/100 [================>.............] - ETA: 36:10 - loss: 1.7759 - rpn_class_loss: 0.0680 - rpn_bbox_loss: 0.3546 - mrcnn_class_loss: 0.2395 - mrcnn_bbox_loss: 0.5445 - mrcnn_mask_loss: 0.5693mask_shape: (202, 308, 5)
#  59/100 [================>.............] - ETA: 35:18 - loss: 1.7767 - rpn_class_loss: 0.0680 - rpn_bbox_loss: 0.3515 - mrcnn_class_loss: 0.2450 - mrcnn_bbox_loss: 0.5444 - mrcnn_mask_loss: 0.5677mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 5)
#  60/100 [=================>............] - ETA: 34:26 - loss: 1.7785 - rpn_class_loss: 0.0681 - rpn_bbox_loss: 0.3484 - mrcnn_class_loss: 0.2512 - mrcnn_bbox_loss: 0.5448 - mrcnn_mask_loss: 0.5661mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 5)
#  61/100 [=================>............] - ETA: 33:33 - loss: 1.7714 - rpn_class_loss: 0.0671 - rpn_bbox_loss: 0.3457 - mrcnn_class_loss: 0.2519 - mrcnn_bbox_loss: 0.5441 - mrcnn_mask_loss: 0.5627mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 7)
#  62/100 [=================>............] - ETA: 32:42 - loss: 1.7630 - rpn_class_loss: 0.0662 - rpn_bbox_loss: 0.3430 - mrcnn_class_loss: 0.2519 - mrcnn_bbox_loss: 0.5422 - mrcnn_mask_loss: 0.5596mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 7)
#  63/100 [=================>............] - ETA: 31:49 - loss: 1.7551 - rpn_class_loss: 0.0659 - rpn_bbox_loss: 0.3396 - mrcnn_class_loss: 0.2515 - mrcnn_bbox_loss: 0.5408 - mrcnn_mask_loss: 0.5573mask_shape: (202, 308, 1)
#  64/100 [==================>...........] - ETA: 30:57 - loss: 1.7469 - rpn_class_loss: 0.0656 - rpn_bbox_loss: 0.3361 - mrcnn_class_loss: 0.2513 - mrcnn_bbox_loss: 0.5387 - mrcnn_mask_loss: 0.5552mask_shape: (202, 308, 1)
#  65/100 [==================>...........] - ETA: 30:05 - loss: 1.7396 - rpn_class_loss: 0.0652 - rpn_bbox_loss: 0.3333 - mrcnn_class_loss: 0.2521 - mrcnn_bbox_loss: 0.5361 - mrcnn_mask_loss: 0.5529mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 4)
#  66/100 [==================>...........] - ETA: 29:13 - loss: 1.7316 - rpn_class_loss: 0.0649 - rpn_bbox_loss: 0.3305 - mrcnn_class_loss: 0.2526 - mrcnn_bbox_loss: 0.5329 - mrcnn_mask_loss: 0.5507mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 4)
#  67/100 [===================>..........] - ETA: 28:21 - loss: 1.7241 - rpn_class_loss: 0.0644 - rpn_bbox_loss: 0.3284 - mrcnn_class_loss: 0.2517 - mrcnn_bbox_loss: 0.5316 - mrcnn_mask_loss: 0.5479mask_shape: (202, 308, 2)
#  68/100 [===================>..........] - ETA: 27:29 - loss: 1.7159 - rpn_class_loss: 0.0640 - rpn_bbox_loss: 0.3262 - mrcnn_class_loss: 0.2505 - mrcnn_bbox_loss: 0.5299 - mrcnn_mask_loss: 0.5452mask_shape: (202, 308, 2)
#  69/100 [===================>..........] - ETA: 26:37 - loss: 1.7136 - rpn_class_loss: 0.0638 - rpn_bbox_loss: 0.3253 - mrcnn_class_loss: 0.2495 - mrcnn_bbox_loss: 0.5316 - mrcnn_mask_loss: 0.5433mask_shape: (202, 308, 4)
#  70/100 [====================>.........] - ETA: 25:45 - loss: 1.7099 - rpn_class_loss: 0.0636 - rpn_bbox_loss: 0.3243 - mrcnn_class_loss: 0.2479 - mrcnn_bbox_loss: 0.5325 - mrcnn_mask_loss: 0.5415mask_shape: (202, 308, 4)
#  71/100 [====================>.........] - ETA: 24:53 - loss: 1.7078 - rpn_class_loss: 0.0634 - rpn_bbox_loss: 0.3230 - mrcnn_class_loss: 0.2490 - mrcnn_bbox_loss: 0.5321 - mrcnn_mask_loss: 0.5403mask_shape: (202, 308, 5)
#  72/100 [====================>.........] - ETA: 24:01 - loss: 1.7044 - rpn_class_loss: 0.0632 - rpn_bbox_loss: 0.3215 - mrcnn_class_loss: 0.2501 - mrcnn_bbox_loss: 0.5306 - mrcnn_mask_loss: 0.5390mask_shape: (202, 308, 5)
#  73/100 [====================>.........] - ETA: 23:09 - loss: 1.6957 - rpn_class_loss: 0.0634 - rpn_bbox_loss: 0.3192 - mrcnn_class_loss: 0.2485 - mrcnn_bbox_loss: 0.5271 - mrcnn_mask_loss: 0.5374mask_shape: (202, 308, 6)
#  74/100 [=====================>........] - ETA: 22:18 - loss: 1.6869 - rpn_class_loss: 0.0635 - rpn_bbox_loss: 0.3169 - mrcnn_class_loss: 0.2468 - mrcnn_bbox_loss: 0.5236 - mrcnn_mask_loss: 0.5361mask_shape: (202, 308, 6)
#  75/100 [=====================>........] - ETA: 21:26 - loss: 1.6859 - rpn_class_loss: 0.0668 - rpn_bbox_loss: 0.3163 - mrcnn_class_loss: 0.2470 - mrcnn_bbox_loss: 0.5213 - mrcnn_mask_loss: 0.5345mask_shape: (202, 308, 5)
#  76/100 [=====================>........] - ETA: 20:34 - loss: 1.6838 - rpn_class_loss: 0.0698 - rpn_bbox_loss: 0.3156 - mrcnn_class_loss: 0.2469 - mrcnn_bbox_loss: 0.5188 - mrcnn_mask_loss: 0.5328mask_shape: (202, 308, 5)
#  77/100 [======================>.......] - ETA: 19:43 - loss: 1.6706 - rpn_class_loss: 0.0692 - rpn_bbox_loss: 0.3122 - mrcnn_class_loss: 0.2442 - mrcnn_bbox_loss: 0.5153 - mrcnn_mask_loss: 0.5296mask_shape: (202, 308, 8)
#  78/100 [======================>.......] - ETA: 18:51 - loss: 1.6571 - rpn_class_loss: 0.0686 - rpn_bbox_loss: 0.3089 - mrcnn_class_loss: 0.2420 - mrcnn_bbox_loss: 0.5111 - mrcnn_mask_loss: 0.5265mask_shape: (202, 308, 8)
#  79/100 [======================>.......] - ETA: 17:59 - loss: 1.6567 - rpn_class_loss: 0.0689 - rpn_bbox_loss: 0.3086 - mrcnn_class_loss: 0.2436 - mrcnn_bbox_loss: 0.5101 - mrcnn_mask_loss: 0.5254mask_shape: (202, 308, 5)
#  80/100 [=======================>......] - ETA: 17:08 - loss: 1.6554 - rpn_class_loss: 0.0692 - rpn_bbox_loss: 0.3084 - mrcnn_class_loss: 0.2453 - mrcnn_bbox_loss: 0.5085 - mrcnn_mask_loss: 0.5240mask_shape: (202, 308, 5)
#  81/100 [=======================>......] - ETA: 16:16 - loss: 1.6529 - rpn_class_loss: 0.0688 - rpn_bbox_loss: 0.3138 - mrcnn_class_loss: 0.2431 - mrcnn_bbox_loss: 0.5057 - mrcnn_mask_loss: 0.5215mask_shape: (202, 308, 2)
#  82/100 [=======================>......] - ETA: 15:25 - loss: 1.6505 - rpn_class_loss: 0.0684 - rpn_bbox_loss: 0.3180 - mrcnn_class_loss: 0.2410 - mrcnn_bbox_loss: 0.5038 - mrcnn_mask_loss: 0.5193mask_shape: (202, 308, 2)
#  83/100 [=======================>......] - ETA: 14:33 - loss: 1.6422 - rpn_class_loss: 0.0677 - rpn_bbox_loss: 0.3155 - mrcnn_class_loss: 0.2390 - mrcnn_bbox_loss: 0.5031 - mrcnn_mask_loss: 0.5170mask_shape: (202, 308, 1)
#  84/100 [========================>.....] - ETA: 13:42 - loss: 1.6334 - rpn_class_loss: 0.0670 - rpn_bbox_loss: 0.3131 - mrcnn_class_loss: 0.2368 - mrcnn_bbox_loss: 0.5018 - mrcnn_mask_loss: 0.5147mask_shape: (202, 308, 1)
#  85/100 [========================>.....] - ETA: 12:50 - loss: 1.6259 - rpn_class_loss: 0.0665 - rpn_bbox_loss: 0.3101 - mrcnn_class_loss: 0.2361 - mrcnn_bbox_loss: 0.4997 - mrcnn_mask_loss: 0.5136mask_shape: (202, 308, 3)
#  86/100 [========================>.....] - ETA: 11:59 - loss: 1.6177 - rpn_class_loss: 0.0659 - rpn_bbox_loss: 0.3070 - mrcnn_class_loss: 0.2354 - mrcnn_bbox_loss: 0.4969 - mrcnn_mask_loss: 0.5126mask_shape: (202, 308, 3)
#  87/100 [=========================>....] - ETA: 11:07 - loss: 1.6152 - rpn_class_loss: 0.0664 - rpn_bbox_loss: 0.3061 - mrcnn_class_loss: 0.2363 - mrcnn_bbox_loss: 0.4952 - mrcnn_mask_loss: 0.5113mask_shape: (202, 308, 5)
#  88/100 [=========================>....] - ETA: 10:16 - loss: 1.6130 - rpn_class_loss: 0.0667 - rpn_bbox_loss: 0.3049 - mrcnn_class_loss: 0.2377 - mrcnn_bbox_loss: 0.4939 - mrcnn_mask_loss: 0.5098mask_shape: (202, 308, 5)
#  89/100 [=========================>....] - ETA: 9:24 - loss: 1.6045 - rpn_class_loss: 0.0661 - rpn_bbox_loss: 0.3026 - mrcnn_class_loss: 0.2353 - mrcnn_bbox_loss: 0.4924 - mrcnn_mask_loss: 0.5080 mask_shape: (202, 308, 7)
#  90/100 [==========================>...] - ETA: 8:33 - loss: 1.5949 - rpn_class_loss: 0.0655 - rpn_bbox_loss: 0.3001 - mrcnn_class_loss: 0.2329 - mrcnn_bbox_loss: 0.4899 - mrcnn_mask_loss: 0.5064mask_shape: (202, 308, 7)
#  91/100 [==========================>...] - ETA: 7:42 - loss: 1.5874 - rpn_class_loss: 0.0650 - rpn_bbox_loss: 0.2982 - mrcnn_class_loss: 0.2325 - mrcnn_bbox_loss: 0.4870 - mrcnn_mask_loss: 0.5047mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 5)
#  92/100 [==========================>...] - ETA: 6:50 - loss: 1.5798 - rpn_class_loss: 0.0646 - rpn_bbox_loss: 0.2962 - mrcnn_class_loss: 0.2320 - mrcnn_bbox_loss: 0.4840 - mrcnn_mask_loss: 0.5030mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 5)
#  93/100 [==========================>...] - ETA: 5:59 - loss: 1.5796 - rpn_class_loss: 0.0645 - rpn_bbox_loss: 0.2958 - mrcnn_class_loss: 0.2329 - mrcnn_bbox_loss: 0.4842 - mrcnn_mask_loss: 0.5021mask_shape: (202, 308, 4)
#  94/100 [===========================>..] - ETA: 5:07 - loss: 1.5774 - rpn_class_loss: 0.0645 - rpn_bbox_loss: 0.2953 - mrcnn_class_loss: 0.2329 - mrcnn_bbox_loss: 0.4834 - mrcnn_mask_loss: 0.5014mask_shape: (202, 308, 4)
#  95/100 [===========================>..] - ETA: 4:16 - loss: 1.5746 - rpn_class_loss: 0.0643 - rpn_bbox_loss: 0.2953 - mrcnn_class_loss: 0.2342 - mrcnn_bbox_loss: 0.4811 - mrcnn_mask_loss: 0.4997mask_shape: (202, 308, 2)
#  96/100 [===========================>..] - ETA: 3:25 - loss: 1.5727 - rpn_class_loss: 0.0641 - rpn_bbox_loss: 0.2950 - mrcnn_class_loss: 0.2367 - mrcnn_bbox_loss: 0.4788 - mrcnn_mask_loss: 0.4982mask_shape: (202, 308, 2)
#  97/100 [============================>.] - ETA: 2:33 - loss: 1.5681 - rpn_class_loss: 0.0639 - rpn_bbox_loss: 0.2929 - mrcnn_class_loss: 0.2349 - mrcnn_bbox_loss: 0.4796 - mrcnn_mask_loss: 0.4968mask_shape: (202, 308, 8)
#  98/100 [============================>.] - ETA: 1:42 - loss: 1.5621 - rpn_class_loss: 0.0637 - rpn_bbox_loss: 0.2907 - mrcnn_class_loss: 0.2330 - mrcnn_bbox_loss: 0.4795 - mrcnn_mask_loss: 0.4953mask_shape: (202, 308, 8)
#  99/100 [============================>.] - ETA: 51s - loss: 1.5620 - rpn_class_loss: 0.0635 - rpn_bbox_loss: 0.2889 - mrcnn_class_loss: 0.2356 - mrcnn_bbox_loss: 0.4800 - mrcnn_mask_loss: 0.4940 mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 9)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 6)
# 100/100 [==============================] - 5936s 59s/step - loss: 1.5610 - rpn_class_loss: 0.0633 - rpn_bbox_loss: 0.2871 - mrcnn_class_loss: 0.2372 - mrcnn_bbox_loss: 0.4806 - mrcnn_mask_loss: 0.4928 - val_loss: 1.2313 - val_rpn_class_loss: 0.0382 - val_rpn_bbox_loss: 0.2099 - val_mrcnn_class_loss: 0.1424 - val_mrcnn_bbox_loss: 0.4685 - val_mrcnn_mask_loss: 0.3722
# mask_shape: (202, 308, 10)
# Epoch 2/5
#   1/100 [..............................] - ETA: 1:25:08 - loss: 1.9836 - rpn_class_loss: 0.0865 - rpn_bbox_loss: 0.3230 - mrcnn_class_loss: 0.3205 - mrcnn_bbox_loss: 0.7514 - mrcnn_mask_loss: 0.5022mask_shape: (202, 308, 6)
#   2/100 [..............................] - ETA: 1:23:48 - loss: 1.9235 - rpn_class_loss: 0.0856 - rpn_bbox_loss: 0.3172 - mrcnn_class_loss: 0.3354 - mrcnn_bbox_loss: 0.6823 - mrcnn_mask_loss: 0.5030mask_shape: (202, 308, 6)
#   3/100 [..............................] - ETA: 1:22:41 - loss: 1.7197 - rpn_class_loss: 0.0723 - rpn_bbox_loss: 0.2572 - mrcnn_class_loss: 0.3025 - mrcnn_bbox_loss: 0.6184 - mrcnn_mask_loss: 0.4693mask_shape: (202, 308, 4)
#   4/100 [>.............................] - ETA: 1:21:59 - loss: 1.5980 - rpn_class_loss: 0.0653 - rpn_bbox_loss: 0.2269 - mrcnn_class_loss: 0.2872 - mrcnn_bbox_loss: 0.5729 - mrcnn_mask_loss: 0.4457mask_shape: (202, 308, 4)
#   5/100 [>.............................] - ETA: 1:21:00 - loss: 1.4226 - rpn_class_loss: 0.0541 - rpn_bbox_loss: 0.2089 - mrcnn_class_loss: 0.2388 - mrcnn_bbox_loss: 0.5064 - mrcnn_mask_loss: 0.4144mask_shape: (202, 308, 6)
#   6/100 [>.............................] - ETA: 1:20:02 - loss: 1.3009 - rpn_class_loss: 0.0466 - rpn_bbox_loss: 0.1973 - mrcnn_class_loss: 0.2058 - mrcnn_bbox_loss: 0.4578 - mrcnn_mask_loss: 0.3933mask_shape: (202, 308, 6)
#   7/100 [=>............................] - ETA: 1:19:05 - loss: 1.2984 - rpn_class_loss: 0.0428 - rpn_bbox_loss: 0.2011 - mrcnn_class_loss: 0.2084 - mrcnn_bbox_loss: 0.4437 - mrcnn_mask_loss: 0.4024mask_shape: (202, 308, 1)
#   8/100 [=>............................] - ETA: 1:18:07 - loss: 1.2907 - rpn_class_loss: 0.0400 - rpn_bbox_loss: 0.2031 - mrcnn_class_loss: 0.2088 - mrcnn_bbox_loss: 0.4319 - mrcnn_mask_loss: 0.4070mask_shape: (202, 308, 1)
#   9/100 [=>............................] - ETA: 1:17:16 - loss: 1.2404 - rpn_class_loss: 0.0412 - rpn_bbox_loss: 0.1939 - mrcnn_class_loss: 0.1883 - mrcnn_bbox_loss: 0.4247 - mrcnn_mask_loss: 0.3923mask_shape: (202, 308, 6)
#  10/100 [==>...........................] - ETA: 1:16:24 - loss: 1.1931 - rpn_class_loss: 0.0421 - rpn_bbox_loss: 0.1862 - mrcnn_class_loss: 0.1725 - mrcnn_bbox_loss: 0.4114 - mrcnn_mask_loss: 0.3809mask_shape: (202, 308, 6)
#  11/100 [==>...........................] - ETA: 1:15:30 - loss: 1.2110 - rpn_class_loss: 0.0428 - rpn_bbox_loss: 0.1888 - mrcnn_class_loss: 0.1823 - mrcnn_bbox_loss: 0.4128 - mrcnn_mask_loss: 0.3845mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 3)
#  12/100 [==>...........................] - ETA: 1:14:38 - loss: 1.2165 - rpn_class_loss: 0.0433 - rpn_bbox_loss: 0.1904 - mrcnn_class_loss: 0.1868 - mrcnn_bbox_loss: 0.4093 - mrcnn_mask_loss: 0.3868mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 3)
#  13/100 [==>...........................] - ETA: 1:13:47 - loss: 1.2563 - rpn_class_loss: 0.0632 - rpn_bbox_loss: 0.2158 - mrcnn_class_loss: 0.1886 - mrcnn_bbox_loss: 0.4043 - mrcnn_mask_loss: 0.3844mask_shape: (202, 308, 3)
#  14/100 [===>..........................] - ETA: 1:12:55 - loss: 1.2920 - rpn_class_loss: 0.0793 - rpn_bbox_loss: 0.2358 - mrcnn_class_loss: 0.1925 - mrcnn_bbox_loss: 0.4024 - mrcnn_mask_loss: 0.3820mask_shape: (202, 308, 3)
#  15/100 [===>..........................] - ETA: 1:12:05 - loss: 1.2673 - rpn_class_loss: 0.0755 - rpn_bbox_loss: 0.2283 - mrcnn_class_loss: 0.1941 - mrcnn_bbox_loss: 0.3926 - mrcnn_mask_loss: 0.3768mask_shape: (202, 308, 6)
#  16/100 [===>..........................] - ETA: 1:11:14 - loss: 1.2414 - rpn_class_loss: 0.0723 - rpn_bbox_loss: 0.2203 - mrcnn_class_loss: 0.1940 - mrcnn_bbox_loss: 0.3830 - mrcnn_mask_loss: 0.3719mask_shape: (202, 308, 6)
#  17/100 [====>.........................] - ETA: 1:10:22 - loss: 1.2063 - rpn_class_loss: 0.0700 - rpn_bbox_loss: 0.2118 - mrcnn_class_loss: 0.1869 - mrcnn_bbox_loss: 0.3734 - mrcnn_mask_loss: 0.3643mask_shape: (202, 308, 3)
#  18/100 [====>.........................] - ETA: 1:09:30 - loss: 1.1742 - rpn_class_loss: 0.0679 - rpn_bbox_loss: 0.2046 - mrcnn_class_loss: 0.1814 - mrcnn_bbox_loss: 0.3635 - mrcnn_mask_loss: 0.3569mask_shape: (202, 308, 3)
#  19/100 [====>.........................] - ETA: 1:08:40 - loss: 1.1693 - rpn_class_loss: 0.0654 - rpn_bbox_loss: 0.2009 - mrcnn_class_loss: 0.1875 - mrcnn_bbox_loss: 0.3591 - mrcnn_mask_loss: 0.3564mask_shape: (202, 308, 9)
#  20/100 [=====>........................] - ETA: 1:07:49 - loss: 1.1623 - rpn_class_loss: 0.0632 - rpn_bbox_loss: 0.1976 - mrcnn_class_loss: 0.1926 - mrcnn_bbox_loss: 0.3535 - mrcnn_mask_loss: 0.3553mask_shape: (202, 308, 9)
#  21/100 [=====>........................] - ETA: 1:06:58 - loss: 1.1489 - rpn_class_loss: 0.0609 - rpn_bbox_loss: 0.1937 - mrcnn_class_loss: 0.1947 - mrcnn_bbox_loss: 0.3477 - mrcnn_mask_loss: 0.3519mask_shape: (202, 308, 6)
#  22/100 [=====>........................] - ETA: 1:06:07 - loss: 1.1364 - rpn_class_loss: 0.0589 - rpn_bbox_loss: 0.1899 - mrcnn_class_loss: 0.1965 - mrcnn_bbox_loss: 0.3422 - mrcnn_mask_loss: 0.3489mask_shape: (202, 308, 6)
#  23/100 [=====>........................] - ETA: 1:05:17 - loss: 1.1437 - rpn_class_loss: 0.0573 - rpn_bbox_loss: 0.1878 - mrcnn_class_loss: 0.2070 - mrcnn_bbox_loss: 0.3426 - mrcnn_mask_loss: 0.3489mask_shape: (202, 308, 8)
#  24/100 [======>.......................] - ETA: 1:04:26 - loss: 1.1466 - rpn_class_loss: 0.0558 - rpn_bbox_loss: 0.1857 - mrcnn_class_loss: 0.2143 - mrcnn_bbox_loss: 0.3420 - mrcnn_mask_loss: 0.3488mask_shape: (202, 308, 8)
#  25/100 [======>.......................] - ETA: 1:03:36 - loss: 1.1548 - rpn_class_loss: 0.0572 - rpn_bbox_loss: 0.1895 - mrcnn_class_loss: 0.2186 - mrcnn_bbox_loss: 0.3412 - mrcnn_mask_loss: 0.3484mask_shape: (202, 308, 1)
#  26/100 [======>.......................] - ETA: 1:02:45 - loss: 1.1582 - rpn_class_loss: 0.0584 - rpn_bbox_loss: 0.1922 - mrcnn_class_loss: 0.2205 - mrcnn_bbox_loss: 0.3383 - mrcnn_mask_loss: 0.3488mask_shape: (202, 308, 1)
#  27/100 [=======>......................] - ETA: 1:01:54 - loss: 1.1607 - rpn_class_loss: 0.0570 - rpn_bbox_loss: 0.1954 - mrcnn_class_loss: 0.2174 - mrcnn_bbox_loss: 0.3449 - mrcnn_mask_loss: 0.3461mask_shape: (202, 308, 4)
#  28/100 [=======>......................] - ETA: 1:01:03 - loss: 1.1584 - rpn_class_loss: 0.0556 - rpn_bbox_loss: 0.1965 - mrcnn_class_loss: 0.2135 - mrcnn_bbox_loss: 0.3487 - mrcnn_mask_loss: 0.3442mask_shape: (202, 308, 4)
#  29/100 [=======>......................] - ETA: 1:00:12 - loss: 1.1488 - rpn_class_loss: 0.0543 - rpn_bbox_loss: 0.1942 - mrcnn_class_loss: 0.2132 - mrcnn_bbox_loss: 0.3436 - mrcnn_mask_loss: 0.3435mask_shape: (202, 308, 11)
#  30/100 [========>.....................] - ETA: 59:22 - loss: 1.1381 - rpn_class_loss: 0.0529 - rpn_bbox_loss: 0.1928 - mrcnn_class_loss: 0.2109 - mrcnn_bbox_loss: 0.3386 - mrcnn_mask_loss: 0.3428  mask_shape: (202, 308, 11)
#  31/100 [========>.....................] - ETA: 58:31 - loss: 1.1317 - rpn_class_loss: 0.0526 - rpn_bbox_loss: 0.1912 - mrcnn_class_loss: 0.2101 - mrcnn_bbox_loss: 0.3376 - mrcnn_mask_loss: 0.3402mask_shape: (202, 308, 9)
#  32/100 [========>.....................] - ETA: 57:40 - loss: 1.1247 - rpn_class_loss: 0.0523 - rpn_bbox_loss: 0.1892 - mrcnn_class_loss: 0.2093 - mrcnn_bbox_loss: 0.3362 - mrcnn_mask_loss: 0.3378mask_shape: (202, 308, 9)
#  33/100 [========>.....................] - ETA: 56:49 - loss: 1.1238 - rpn_class_loss: 0.0512 - rpn_bbox_loss: 0.1915 - mrcnn_class_loss: 0.2052 - mrcnn_bbox_loss: 0.3367 - mrcnn_mask_loss: 0.3391mask_shape: (202, 308, 2)
#  34/100 [=========>....................] - ETA: 55:58 - loss: 1.1196 - rpn_class_loss: 0.0502 - rpn_bbox_loss: 0.1935 - mrcnn_class_loss: 0.2009 - mrcnn_bbox_loss: 0.3357 - mrcnn_mask_loss: 0.3393mask_shape: (202, 308, 2)
#  35/100 [=========>....................] - ETA: 55:07 - loss: 1.1202 - rpn_class_loss: 0.0493 - rpn_bbox_loss: 0.2041 - mrcnn_class_loss: 0.1968 - mrcnn_bbox_loss: 0.3326 - mrcnn_mask_loss: 0.3374mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 9)
#  36/100 [=========>....................] - ETA: 54:15 - loss: 1.1184 - rpn_class_loss: 0.0484 - rpn_bbox_loss: 0.2141 - mrcnn_class_loss: 0.1930 - mrcnn_bbox_loss: 0.3274 - mrcnn_mask_loss: 0.3355mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 9)
#  37/100 [==========>...................] - ETA: 53:25 - loss: 1.1198 - rpn_class_loss: 0.0473 - rpn_bbox_loss: 0.2152 - mrcnn_class_loss: 0.1924 - mrcnn_bbox_loss: 0.3294 - mrcnn_mask_loss: 0.3356mask_shape: (202, 308, 9)
#  38/100 [==========>...................] - ETA: 52:33 - loss: 1.1179 - rpn_class_loss: 0.0462 - rpn_bbox_loss: 0.2157 - mrcnn_class_loss: 0.1908 - mrcnn_bbox_loss: 0.3299 - mrcnn_mask_loss: 0.3352mask_shape: (202, 308, 9)
#  39/100 [==========>...................] - ETA: 51:42 - loss: 1.1186 - rpn_class_loss: 0.0451 - rpn_bbox_loss: 0.2163 - mrcnn_class_loss: 0.1866 - mrcnn_bbox_loss: 0.3362 - mrcnn_mask_loss: 0.3344mask_shape: (202, 308, 2)
#  40/100 [===========>..................] - ETA: 50:51 - loss: 1.1143 - rpn_class_loss: 0.0440 - rpn_bbox_loss: 0.2154 - mrcnn_class_loss: 0.1824 - mrcnn_bbox_loss: 0.3397 - mrcnn_mask_loss: 0.3327mask_shape: (202, 308, 2)
#  41/100 [===========>..................] - ETA: 50:00 - loss: 1.1048 - rpn_class_loss: 0.0434 - rpn_bbox_loss: 0.2121 - mrcnn_class_loss: 0.1783 - mrcnn_bbox_loss: 0.3382 - mrcnn_mask_loss: 0.3327mask_shape: (202, 308, 4)
#  42/100 [===========>..................] - ETA: 49:09 - loss: 1.0941 - rpn_class_loss: 0.0428 - rpn_bbox_loss: 0.2088 - mrcnn_class_loss: 0.1744 - mrcnn_bbox_loss: 0.3353 - mrcnn_mask_loss: 0.3328mask_shape: (202, 308, 4)
#  43/100 [===========>..................] - ETA: 48:17 - loss: 1.1017 - rpn_class_loss: 0.0427 - rpn_bbox_loss: 0.2140 - mrcnn_class_loss: 0.1727 - mrcnn_bbox_loss: 0.3390 - mrcnn_mask_loss: 0.3333mask_shape: (202, 308, 2)
#  44/100 [============>.................] - ETA: 47:26 - loss: 1.1060 - rpn_class_loss: 0.0426 - rpn_bbox_loss: 0.2181 - mrcnn_class_loss: 0.1708 - mrcnn_bbox_loss: 0.3413 - mrcnn_mask_loss: 0.3332mask_shape: (202, 308, 2)
#  45/100 [============>.................] - ETA: 46:35 - loss: 1.1034 - rpn_class_loss: 0.0441 - rpn_bbox_loss: 0.2218 - mrcnn_class_loss: 0.1684 - mrcnn_bbox_loss: 0.3382 - mrcnn_mask_loss: 0.3308mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 4)
#  46/100 [============>.................] - ETA: 45:44 - loss: 1.0984 - rpn_class_loss: 0.0454 - rpn_bbox_loss: 0.2249 - mrcnn_class_loss: 0.1661 - mrcnn_bbox_loss: 0.3342 - mrcnn_mask_loss: 0.3278mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 4)
#  47/100 [=============>................] - ETA: 44:53 - loss: 1.0896 - rpn_class_loss: 0.0446 - rpn_bbox_loss: 0.2228 - mrcnn_class_loss: 0.1642 - mrcnn_bbox_loss: 0.3337 - mrcnn_mask_loss: 0.3244mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 7)
#  48/100 [=============>................] - ETA: 44:02 - loss: 1.0809 - rpn_class_loss: 0.0437 - rpn_bbox_loss: 0.2206 - mrcnn_class_loss: 0.1626 - mrcnn_bbox_loss: 0.3330 - mrcnn_mask_loss: 0.3210mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 7)
#  49/100 [=============>................] - ETA: 43:11 - loss: 1.0730 - rpn_class_loss: 0.0431 - rpn_bbox_loss: 0.2183 - mrcnn_class_loss: 0.1630 - mrcnn_bbox_loss: 0.3303 - mrcnn_mask_loss: 0.3183mask_shape: (202, 308, 4)
#  50/100 [==============>...............] - ETA: 42:20 - loss: 1.0625 - rpn_class_loss: 0.0425 - rpn_bbox_loss: 0.2156 - mrcnn_class_loss: 0.1617 - mrcnn_bbox_loss: 0.3268 - mrcnn_mask_loss: 0.3158mask_shape: (202, 308, 4)
#  51/100 [==============>...............] - ETA: 41:29 - loss: 1.0694 - rpn_class_loss: 0.0421 - rpn_bbox_loss: 0.2163 - mrcnn_class_loss: 0.1628 - mrcnn_bbox_loss: 0.3299 - mrcnn_mask_loss: 0.3183mask_shape: (202, 308, 5)
#  52/100 [==============>...............] - ETA: 40:39 - loss: 1.0747 - rpn_class_loss: 0.0417 - rpn_bbox_loss: 0.2166 - mrcnn_class_loss: 0.1637 - mrcnn_bbox_loss: 0.3323 - mrcnn_mask_loss: 0.3203mask_shape: (202, 308, 5)
#  53/100 [==============>...............] - ETA: 39:48 - loss: 1.0761 - rpn_class_loss: 0.0413 - rpn_bbox_loss: 0.2146 - mrcnn_class_loss: 0.1668 - mrcnn_bbox_loss: 0.3332 - mrcnn_mask_loss: 0.3201mask_shape: (202, 308, 5)
#  54/100 [===============>..............] - ETA: 38:57 - loss: 1.0753 - rpn_class_loss: 0.0409 - rpn_bbox_loss: 0.2125 - mrcnn_class_loss: 0.1688 - mrcnn_bbox_loss: 0.3333 - mrcnn_mask_loss: 0.3198mask_shape: (202, 308, 5)
#  55/100 [===============>..............] - ETA: 38:06 - loss: 1.0880 - rpn_class_loss: 0.0424 - rpn_bbox_loss: 0.2114 - mrcnn_class_loss: 0.1777 - mrcnn_bbox_loss: 0.3350 - mrcnn_mask_loss: 0.3215mask_shape: (202, 308, 3)
#  56/100 [===============>..............] - ETA: 37:15 - loss: 1.1000 - rpn_class_loss: 0.0436 - rpn_bbox_loss: 0.2102 - mrcnn_class_loss: 0.1864 - mrcnn_bbox_loss: 0.3365 - mrcnn_mask_loss: 0.3233mask_shape: (202, 308, 3)
#  57/100 [================>.............] - ETA: 36:24 - loss: 1.0956 - rpn_class_loss: 0.0430 - rpn_bbox_loss: 0.2092 - mrcnn_class_loss: 0.1861 - mrcnn_bbox_loss: 0.3362 - mrcnn_mask_loss: 0.3211mask_shape: (202, 308, 3)
#  58/100 [================>.............] - ETA: 35:33 - loss: 1.0911 - rpn_class_loss: 0.0424 - rpn_bbox_loss: 0.2080 - mrcnn_class_loss: 0.1861 - mrcnn_bbox_loss: 0.3355 - mrcnn_mask_loss: 0.3192mask_shape: (202, 308, 3)
#  59/100 [================>.............] - ETA: 34:42 - loss: 1.0947 - rpn_class_loss: 0.0423 - rpn_bbox_loss: 0.2069 - mrcnn_class_loss: 0.1876 - mrcnn_bbox_loss: 0.3380 - mrcnn_mask_loss: 0.3199mask_shape: (202, 308, 3)
#  60/100 [=================>............] - ETA: 33:51 - loss: 1.0965 - rpn_class_loss: 0.0421 - rpn_bbox_loss: 0.2060 - mrcnn_class_loss: 0.1891 - mrcnn_bbox_loss: 0.3393 - mrcnn_mask_loss: 0.3200mask_shape: (202, 308, 3)
#  61/100 [=================>............] - ETA: 33:00 - loss: 1.1015 - rpn_class_loss: 0.0417 - rpn_bbox_loss: 0.2088 - mrcnn_class_loss: 0.1886 - mrcnn_bbox_loss: 0.3409 - mrcnn_mask_loss: 0.3215mask_shape: (202, 308, 10)
#  62/100 [=================>............] - ETA: 32:09 - loss: 1.1047 - rpn_class_loss: 0.0413 - rpn_bbox_loss: 0.2115 - mrcnn_class_loss: 0.1880 - mrcnn_bbox_loss: 0.3413 - mrcnn_mask_loss: 0.3226mask_shape: (202, 308, 10)
#  63/100 [=================>............] - ETA: 31:18 - loss: 1.1125 - rpn_class_loss: 0.0416 - rpn_bbox_loss: 0.2127 - mrcnn_class_loss: 0.1914 - mrcnn_bbox_loss: 0.3433 - mrcnn_mask_loss: 0.3235mask_shape: (202, 308, 9)
#  64/100 [==================>...........] - ETA: 30:27 - loss: 1.1178 - rpn_class_loss: 0.0418 - rpn_bbox_loss: 0.2134 - mrcnn_class_loss: 0.1932 - mrcnn_bbox_loss: 0.3452 - mrcnn_mask_loss: 0.3242mask_shape: (202, 308, 9)
#  65/100 [==================>...........] - ETA: 29:36 - loss: 1.1064 - rpn_class_loss: 0.0414 - rpn_bbox_loss: 0.2122 - mrcnn_class_loss: 0.1903 - mrcnn_bbox_loss: 0.3414 - mrcnn_mask_loss: 0.3211mask_shape: (202, 308, 6)
#  66/100 [==================>...........] - ETA: 28:45 - loss: 1.0951 - rpn_class_loss: 0.0410 - rpn_bbox_loss: 0.2108 - mrcnn_class_loss: 0.1875 - mrcnn_bbox_loss: 0.3378 - mrcnn_mask_loss: 0.3180mask_shape: (202, 308, 6)
#  67/100 [===================>..........] - ETA: 27:55 - loss: 1.0974 - rpn_class_loss: 0.0407 - rpn_bbox_loss: 0.2095 - mrcnn_class_loss: 0.1893 - mrcnn_bbox_loss: 0.3375 - mrcnn_mask_loss: 0.3204mask_shape: (202, 308, 3)
# ...
#  36/100 [=========>....................] - ETA: 54:04 - loss: 0.9461 - rpn_class_loss: 0.0228 - rpn_bbox_loss: 0.1785 - mrcnn_class_loss: 0.2208 - mrcnn_bbox_loss: 0.2417 - mrcnn_mask_loss: 0.2822mask_shape: (202, 308, 1)
#  37/100 [==========>...................] - ETA: 53:13 - loss: 0.9385 - rpn_class_loss: 0.0227 - rpn_bbox_loss: 0.1773 - mrcnn_class_loss: 0.2195 - mrcnn_bbox_loss: 0.2384 - mrcnn_mask_loss: 0.2806mask_shape: (202, 308, 2)
#  38/100 [==========>...................] - ETA: 52:22 - loss: 0.9319 - rpn_class_loss: 0.0226 - rpn_bbox_loss: 0.1759 - mrcnn_class_loss: 0.2187 - mrcnn_bbox_loss: 0.2355 - mrcnn_mask_loss: 0.2793mask_shape: (202, 308, 2)
#  39/100 [==========>...................] - ETA: 51:31 - loss: 0.9396 - rpn_class_loss: 0.0227 - rpn_bbox_loss: 0.1786 - mrcnn_class_loss: 0.2207 - mrcnn_bbox_loss: 0.2370 - mrcnn_mask_loss: 0.2806mask_shape: (202, 308, 8)
#  40/100 [===========>..................] - ETA: 50:40 - loss: 0.9465 - rpn_class_loss: 0.0228 - rpn_bbox_loss: 0.1811 - mrcnn_class_loss: 0.2224 - mrcnn_bbox_loss: 0.2387 - mrcnn_mask_loss: 0.2815mask_shape: (202, 308, 8)
#  41/100 [===========>..................] - ETA: 49:50 - loss: 0.9426 - rpn_class_loss: 0.0229 - rpn_bbox_loss: 0.1797 - mrcnn_class_loss: 0.2214 - mrcnn_bbox_loss: 0.2377 - mrcnn_mask_loss: 0.2809mask_shape: (202, 308, 6)
#  42/100 [===========>..................] - ETA: 48:59 - loss: 0.9391 - rpn_class_loss: 0.0230 - rpn_bbox_loss: 0.1782 - mrcnn_class_loss: 0.2215 - mrcnn_bbox_loss: 0.2361 - mrcnn_mask_loss: 0.2803mask_shape: (202, 308, 6)
#  43/100 [===========>..................] - ETA: 48:09 - loss: 0.9554 - rpn_class_loss: 0.0262 - rpn_bbox_loss: 0.1859 - mrcnn_class_loss: 0.2202 - mrcnn_bbox_loss: 0.2412 - mrcnn_mask_loss: 0.2818mask_shape: (202, 308, 7)
#  44/100 [============>.................] - ETA: 47:18 - loss: 0.9720 - rpn_class_loss: 0.0293 - rpn_bbox_loss: 0.1931 - mrcnn_class_loss: 0.2195 - mrcnn_bbox_loss: 0.2467 - mrcnn_mask_loss: 0.2835mask_shape: (202, 308, 7)
#  45/100 [============>.................] - ETA: 46:28 - loss: 0.9794 - rpn_class_loss: 0.0303 - rpn_bbox_loss: 0.1938 - mrcnn_class_loss: 0.2212 - mrcnn_bbox_loss: 0.2485 - mrcnn_mask_loss: 0.2856mask_shape: (202, 308, 13)
#  46/100 [============>.................] - ETA: 45:37 - loss: 0.9843 - rpn_class_loss: 0.0312 - rpn_bbox_loss: 0.1943 - mrcnn_class_loss: 0.2218 - mrcnn_bbox_loss: 0.2498 - mrcnn_mask_loss: 0.2872mask_shape: (202, 308, 13)
#  47/100 [=============>................] - ETA: 44:46 - loss: 0.9889 - rpn_class_loss: 0.0338 - rpn_bbox_loss: 0.1943 - mrcnn_class_loss: 0.2237 - mrcnn_bbox_loss: 0.2502 - mrcnn_mask_loss: 0.2870mask_shape: (202, 308, 3)
#  48/100 [=============>................] - ETA: 43:55 - loss: 0.9941 - rpn_class_loss: 0.0358 - rpn_bbox_loss: 0.1942 - mrcnn_class_loss: 0.2262 - mrcnn_bbox_loss: 0.2507 - mrcnn_mask_loss: 0.2870mask_shape: (202, 308, 3)
#  49/100 [=============>................] - ETA: 43:04 - loss: 0.9921 - rpn_class_loss: 0.0353 - rpn_bbox_loss: 0.1926 - mrcnn_class_loss: 0.2225 - mrcnn_bbox_loss: 0.2533 - mrcnn_mask_loss: 0.2884mask_shape: (202, 308, 13)
#  50/100 [==============>...............] - ETA: 42:13 - loss: 0.9896 - rpn_class_loss: 0.0348 - rpn_bbox_loss: 0.1909 - mrcnn_class_loss: 0.2190 - mrcnn_bbox_loss: 0.2549 - mrcnn_mask_loss: 0.2900mask_shape: (202, 308, 13)
#  51/100 [==============>...............] - ETA: 41:23 - loss: 0.9921 - rpn_class_loss: 0.0351 - rpn_bbox_loss: 0.1895 - mrcnn_class_loss: 0.2208 - mrcnn_bbox_loss: 0.2561 - mrcnn_mask_loss: 0.2906mask_shape: (202, 308, 2)
#  52/100 [==============>...............] - ETA: 40:32 - loss: 0.9953 - rpn_class_loss: 0.0354 - rpn_bbox_loss: 0.1881 - mrcnn_class_loss: 0.2231 - mrcnn_bbox_loss: 0.2573 - mrcnn_mask_loss: 0.2915mask_shape: (202, 308, 2)
#  53/100 [==============>...............] - ETA: 39:41 - loss: 0.9978 - rpn_class_loss: 0.0348 - rpn_bbox_loss: 0.1862 - mrcnn_class_loss: 0.2238 - mrcnn_bbox_loss: 0.2602 - mrcnn_mask_loss: 0.2928mask_shape: (202, 308, 7)
#  54/100 [===============>..............] - ETA: 38:51 - loss: 1.0005 - rpn_class_loss: 0.0343 - rpn_bbox_loss: 0.1843 - mrcnn_class_loss: 0.2252 - mrcnn_bbox_loss: 0.2625 - mrcnn_mask_loss: 0.2942mask_shape: (202, 308, 7)
#  55/100 [===============>..............] - ETA: 38:01 - loss: 0.9983 - rpn_class_loss: 0.0342 - rpn_bbox_loss: 0.1875 - mrcnn_class_loss: 0.2222 - mrcnn_bbox_loss: 0.2616 - mrcnn_mask_loss: 0.2928mask_shape: (202, 308, 7)
#  56/100 [===============>..............] - ETA: 37:10 - loss: 0.9952 - rpn_class_loss: 0.0341 - rpn_bbox_loss: 0.1902 - mrcnn_class_loss: 0.2193 - mrcnn_bbox_loss: 0.2603 - mrcnn_mask_loss: 0.2913mask_shape: (202, 308, 7)
#  57/100 [================>.............] - ETA: 36:19 - loss: 0.9964 - rpn_class_loss: 0.0340 - rpn_bbox_loss: 0.1946 - mrcnn_class_loss: 0.2176 - mrcnn_bbox_loss: 0.2591 - mrcnn_mask_loss: 0.2911mask_shape: (202, 308, 6)
#  58/100 [================>.............] - ETA: 35:29 - loss: 0.9967 - rpn_class_loss: 0.0339 - rpn_bbox_loss: 0.1985 - mrcnn_class_loss: 0.2153 - mrcnn_bbox_loss: 0.2580 - mrcnn_mask_loss: 0.2909mask_shape: (202, 308, 6)
#  59/100 [================>.............] - ETA: 34:39 - loss: 0.9956 - rpn_class_loss: 0.0337 - rpn_bbox_loss: 0.1998 - mrcnn_class_loss: 0.2120 - mrcnn_bbox_loss: 0.2597 - mrcnn_mask_loss: 0.2905mask_shape: (202, 308, 3)
#  60/100 [=================>............] - ETA: 33:48 - loss: 0.9929 - rpn_class_loss: 0.0336 - rpn_bbox_loss: 0.2007 - mrcnn_class_loss: 0.2086 - mrcnn_bbox_loss: 0.2599 - mrcnn_mask_loss: 0.2901mask_shape: (202, 308, 3)
#  61/100 [=================>............] - ETA: 32:57 - loss: 0.9839 - rpn_class_loss: 0.0333 - rpn_bbox_loss: 0.2000 - mrcnn_class_loss: 0.2053 - mrcnn_bbox_loss: 0.2566 - mrcnn_mask_loss: 0.2886mask_shape: (202, 308, 4)
#  62/100 [=================>............] - ETA: 32:06 - loss: 0.9746 - rpn_class_loss: 0.0331 - rpn_bbox_loss: 0.1989 - mrcnn_class_loss: 0.2024 - mrcnn_bbox_loss: 0.2531 - mrcnn_mask_loss: 0.2871mask_shape: (202, 308, 4)
#  63/100 [=================>............] - ETA: 31:15 - loss: 0.9661 - rpn_class_loss: 0.0327 - rpn_bbox_loss: 0.1964 - mrcnn_class_loss: 0.1999 - mrcnn_bbox_loss: 0.2518 - mrcnn_mask_loss: 0.2853mask_shape: (202, 308, 6)
#  64/100 [==================>...........] - ETA: 30:24 - loss: 0.9572 - rpn_class_loss: 0.0323 - rpn_bbox_loss: 0.1940 - mrcnn_class_loss: 0.1972 - mrcnn_bbox_loss: 0.2503 - mrcnn_mask_loss: 0.2834mask_shape: (202, 308, 6)
#  65/100 [==================>...........] - ETA: 29:34 - loss: 0.9490 - rpn_class_loss: 0.0322 - rpn_bbox_loss: 0.1914 - mrcnn_class_loss: 0.1954 - mrcnn_bbox_loss: 0.2480 - mrcnn_mask_loss: 0.2820mask_shape: (202, 308, 4)
#  66/100 [==================>...........] - ETA: 28:43 - loss: 0.9408 - rpn_class_loss: 0.0320 - rpn_bbox_loss: 0.1890 - mrcnn_class_loss: 0.1939 - mrcnn_bbox_loss: 0.2454 - mrcnn_mask_loss: 0.2805mask_shape: (202, 308, 4)
#  67/100 [===================>..........] - ETA: 27:52 - loss: 0.9409 - rpn_class_loss: 0.0316 - rpn_bbox_loss: 0.1893 - mrcnn_class_loss: 0.1947 - mrcnn_bbox_loss: 0.2452 - mrcnn_mask_loss: 0.2801mask_shape: (202, 308, 3)
#  68/100 [===================>..........] - ETA: 27:01 - loss: 0.9403 - rpn_class_loss: 0.0312 - rpn_bbox_loss: 0.1896 - mrcnn_class_loss: 0.1954 - mrcnn_bbox_loss: 0.2444 - mrcnn_mask_loss: 0.2797mask_shape: (202, 308, 3)
#  69/100 [===================>..........] - ETA: 26:11 - loss: 0.9430 - rpn_class_loss: 0.0318 - rpn_bbox_loss: 0.1903 - mrcnn_class_loss: 0.1980 - mrcnn_bbox_loss: 0.2436 - mrcnn_mask_loss: 0.2792mask_shape: (202, 308, 2)
#  70/100 [====================>.........] - ETA: 25:20 - loss: 0.9454 - rpn_class_loss: 0.0323 - rpn_bbox_loss: 0.1908 - mrcnn_class_loss: 0.2010 - mrcnn_bbox_loss: 0.2426 - mrcnn_mask_loss: 0.2788mask_shape: (202, 308, 2)
#  71/100 [====================>.........] - ETA: 24:30 - loss: 0.9449 - rpn_class_loss: 0.0323 - rpn_bbox_loss: 0.1895 - mrcnn_class_loss: 0.2029 - mrcnn_bbox_loss: 0.2418 - mrcnn_mask_loss: 0.2785mask_shape: (202, 308, 5)
#  72/100 [====================>.........] - ETA: 23:39 - loss: 0.9455 - rpn_class_loss: 0.0323 - rpn_bbox_loss: 0.1881 - mrcnn_class_loss: 0.2052 - mrcnn_bbox_loss: 0.2413 - mrcnn_mask_loss: 0.2785mask_shape: (202, 308, 5)
#  73/100 [====================>.........] - ETA: 22:48 - loss: 0.9603 - rpn_class_loss: 0.0327 - rpn_bbox_loss: 0.1964 - mrcnn_class_loss: 0.2053 - mrcnn_bbox_loss: 0.2447 - mrcnn_mask_loss: 0.2812mask_shape: (202, 308, 10)
#  74/100 [=====================>........] - ETA: 21:58 - loss: 0.9733 - rpn_class_loss: 0.0331 - rpn_bbox_loss: 0.2041 - mrcnn_class_loss: 0.2048 - mrcnn_bbox_loss: 0.2476 - mrcnn_mask_loss: 0.2837mask_shape: (202, 308, 10)
#  75/100 [=====================>........] - ETA: 21:07 - loss: 0.9753 - rpn_class_loss: 0.0328 - rpn_bbox_loss: 0.2073 - mrcnn_class_loss: 0.2026 - mrcnn_bbox_loss: 0.2485 - mrcnn_mask_loss: 0.2842mask_shape: (202, 308, 7)
#  76/100 [=====================>........] - ETA: 20:16 - loss: 0.9766 - rpn_class_loss: 0.0326 - rpn_bbox_loss: 0.2102 - mrcnn_class_loss: 0.2003 - mrcnn_bbox_loss: 0.2490 - mrcnn_mask_loss: 0.2845mask_shape: (202, 308, 7)
#  77/100 [======================>.......] - ETA: 19:26 - loss: 0.9764 - rpn_class_loss: 0.0328 - rpn_bbox_loss: 0.2109 - mrcnn_class_loss: 0.1996 - mrcnn_bbox_loss: 0.2483 - mrcnn_mask_loss: 0.2848mask_shape: (202, 308, 13)
#  78/100 [======================>.......] - ETA: 18:35 - loss: 0.9753 - rpn_class_loss: 0.0330 - rpn_bbox_loss: 0.2114 - mrcnn_class_loss: 0.1986 - mrcnn_bbox_loss: 0.2474 - mrcnn_mask_loss: 0.2850mask_shape: (202, 308, 13)
#  79/100 [======================>.......] - ETA: 17:45 - loss: 0.9809 - rpn_class_loss: 0.0334 - rpn_bbox_loss: 0.2133 - mrcnn_class_loss: 0.2012 - mrcnn_bbox_loss: 0.2475 - mrcnn_mask_loss: 0.2856mask_shape: (202, 308, 10)
#  80/100 [=======================>......] - ETA: 16:54 - loss: 0.9852 - rpn_class_loss: 0.0337 - rpn_bbox_loss: 0.2150 - mrcnn_class_loss: 0.2038 - mrcnn_bbox_loss: 0.2471 - mrcnn_mask_loss: 0.2857mask_shape: (202, 308, 10)
#  81/100 [=======================>......] - ETA: 16:03 - loss: 0.9853 - rpn_class_loss: 0.0337 - rpn_bbox_loss: 0.2135 - mrcnn_class_loss: 0.2057 - mrcnn_bbox_loss: 0.2469 - mrcnn_mask_loss: 0.2856mask_shape: (202, 308, 2)
#  82/100 [=======================>......] - ETA: 15:12 - loss: 0.9858 - rpn_class_loss: 0.0336 - rpn_bbox_loss: 0.2121 - mrcnn_class_loss: 0.2080 - mrcnn_bbox_loss: 0.2466 - mrcnn_mask_loss: 0.2855mask_shape: (202, 308, 2)
#  83/100 [=======================>......] - ETA: 14:22 - loss: 0.9824 - rpn_class_loss: 0.0335 - rpn_bbox_loss: 0.2103 - mrcnn_class_loss: 0.2087 - mrcnn_bbox_loss: 0.2453 - mrcnn_mask_loss: 0.2846mask_shape: (202, 308, 4)
#  84/100 [========================>.....] - ETA: 13:31 - loss: 0.9783 - rpn_class_loss: 0.0334 - rpn_bbox_loss: 0.2085 - mrcnn_class_loss: 0.2087 - mrcnn_bbox_loss: 0.2439 - mrcnn_mask_loss: 0.2838mask_shape: (202, 308, 4)
#  85/100 [========================>.....] - ETA: 12:40 - loss: 0.9799 - rpn_class_loss: 0.0334 - rpn_bbox_loss: 0.2090 - mrcnn_class_loss: 0.2095 - mrcnn_bbox_loss: 0.2440 - mrcnn_mask_loss: 0.2841mask_shape: (202, 308, 5)
#  86/100 [========================>.....] - ETA: 11:49 - loss: 0.9806 - rpn_class_loss: 0.0333 - rpn_bbox_loss: 0.2093 - mrcnn_class_loss: 0.2102 - mrcnn_bbox_loss: 0.2437 - mrcnn_mask_loss: 0.2841mask_shape: (202, 308, 5)
#  87/100 [=========================>....] - ETA: 10:59 - loss: 0.9855 - rpn_class_loss: 0.0330 - rpn_bbox_loss: 0.2100 - mrcnn_class_loss: 0.2113 - mrcnn_bbox_loss: 0.2460 - mrcnn_mask_loss: 0.2853mask_shape: (202, 308, 4)
#  88/100 [=========================>....] - ETA: 10:08 - loss: 0.9907 - rpn_class_loss: 0.0327 - rpn_bbox_loss: 0.2106 - mrcnn_class_loss: 0.2129 - mrcnn_bbox_loss: 0.2481 - mrcnn_mask_loss: 0.2865mask_shape: (202, 308, 4)
#  89/100 [=========================>....] - ETA: 9:17 - loss: 0.9901 - rpn_class_loss: 0.0325 - rpn_bbox_loss: 0.2124 - mrcnn_class_loss: 0.2116 - mrcnn_bbox_loss: 0.2476 - mrcnn_mask_loss: 0.2860 mask_shape: (202, 308, 2)
#  90/100 [==========================>...] - ETA: 8:27 - loss: 0.9886 - rpn_class_loss: 0.0323 - rpn_bbox_loss: 0.2139 - mrcnn_class_loss: 0.2103 - mrcnn_bbox_loss: 0.2467 - mrcnn_mask_loss: 0.2855mask_shape: (202, 308, 2)
#  91/100 [==========================>...] - ETA: 7:36 - loss: 0.9969 - rpn_class_loss: 0.0327 - rpn_bbox_loss: 0.2195 - mrcnn_class_loss: 0.2100 - mrcnn_bbox_loss: 0.2481 - mrcnn_mask_loss: 0.2867mask_shape: (202, 308, 10)
#  92/100 [==========================>...] - ETA: 6:45 - loss: 1.0041 - rpn_class_loss: 0.0330 - rpn_bbox_loss: 0.2245 - mrcnn_class_loss: 0.2097 - mrcnn_bbox_loss: 0.2492 - mrcnn_mask_loss: 0.2876mask_shape: (202, 308, 10)
#  93/100 [==========================>...] - ETA: 5:54 - loss: 0.9971 - rpn_class_loss: 0.0328 - rpn_bbox_loss: 0.2230 - mrcnn_class_loss: 0.2076 - mrcnn_bbox_loss: 0.2475 - mrcnn_mask_loss: 0.2862mask_shape: (202, 308, 9)
#  94/100 [===========================>..] - ETA: 5:04 - loss: 0.9898 - rpn_class_loss: 0.0326 - rpn_bbox_loss: 0.2214 - mrcnn_class_loss: 0.2055 - mrcnn_bbox_loss: 0.2455 - mrcnn_mask_loss: 0.2847mask_shape: (202, 308, 9)
#  95/100 [===========================>..] - ETA: 4:13 - loss: 0.9891 - rpn_class_loss: 0.0324 - rpn_bbox_loss: 0.2227 - mrcnn_class_loss: 0.2039 - mrcnn_bbox_loss: 0.2454 - mrcnn_mask_loss: 0.2847mask_shape: (202, 308, 9)
#  96/100 [===========================>..] - ETA: 3:22 - loss: 0.9876 - rpn_class_loss: 0.0322 - rpn_bbox_loss: 0.2232 - mrcnn_class_loss: 0.2022 - mrcnn_bbox_loss: 0.2453 - mrcnn_mask_loss: 0.2846mask_shape: (202, 308, 9)
#  97/100 [============================>.] - ETA: 2:32 - loss: 0.9896 - rpn_class_loss: 0.0322 - rpn_bbox_loss: 0.2233 - mrcnn_class_loss: 0.2036 - mrcnn_bbox_loss: 0.2459 - mrcnn_mask_loss: 0.2846mask_shape: (202, 308, 4)
#  98/100 [============================>.] - ETA: 1:41 - loss: 0.9915 - rpn_class_loss: 0.0322 - rpn_bbox_loss: 0.2233 - mrcnn_class_loss: 0.2048 - mrcnn_bbox_loss: 0.2466 - mrcnn_mask_loss: 0.2845mask_shape: (202, 308, 4)
#  99/100 [============================>.] - ETA: 50s - loss: 0.9913 - rpn_class_loss: 0.0320 - rpn_bbox_loss: 0.2238 - mrcnn_class_loss: 0.2041 - mrcnn_bbox_loss: 0.2462 - mrcnn_mask_loss: 0.2852 mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 1)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 10)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 0)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 6)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 8)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 7)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 3)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 2)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 5)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 4)
# mask_shape: (202, 308, 3)
# 100/100 [==============================] - 5875s 59s/step - loss: 0.9911 - rpn_class_loss: 0.0318 - rpn_bbox_loss: 0.2240 - mrcnn_class_loss: 0.2033 - mrcnn_bbox_loss: 0.2460 - mrcnn_mask_loss: 0.2859 - val_loss: 1.0707 - val_rpn_class_loss: 0.0345 - val_rpn_bbox_loss: 0.2566 - val_mrcnn_class_loss: 0.2202 - val_mrcnn_bbox_loss: 0.2616 - val_mrcnn_mask_loss: 0.2977

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. 
# model.train(dataset_train, dataset_val, 
#             learning_rate=config.LEARNING_RATE / 10,
#             epochs=5, 
#             layers="all")

# %%
# Save weights
# Typically not needed because callbacks save after every epoch, Uncomment to save manually
# model_path = os.path.join(MODEL_DIR, "mask_rcnn_apples.h5")
# model.keras_model.save_weights(model_path)

# %% [markdown]
# # Detection

# %%
### Override the training configurations with a few changes for inferencing.
class InferenceConfig(config.__class__):
    # Run detection on one image at a time
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()
inference_config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           apple
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
### Device to load the neural network on.
# Useful if you're training a model on the same 
# machine, in which case use CPU and leave the
# GPU for training.
DEVICE = "/gpu:0"  # /cpu:0 or /gpu:0

# %%
### Create model object in inference mode.
with tf.device(DEVICE):
  model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR, config=inference_config)

# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
model_path = model.find_last()

# Load trained weights
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# W0729 09:51:17.107874 140428436277120 deprecation_wrapper.py:119] From /content/drive/My Drive/Mask_RCNN/mrcnn/model.py:720: The name tf.sets.set_intersection is deprecated. Please use tf.sets.intersection instead.
#
# W0729 09:51:17.224529 140428436277120 deprecation.py:323] From /content/drive/My Drive/Mask_RCNN/mrcnn/model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# Loading weights from  /content/drive/My Drive/Mask_RCNN/logs/apple20190728T1742/mask_rcnn_apple_0005.h5
# Re-starting from epoch 5

# %%
### Run Detection
image_id = random.choice(dataset_val.image_ids)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_val, inference_config, image_id, use_mini_mask=False)
info = dataset_val.image_info[image_id]
print("image ID: {}.{} ({}) {}".format(info["source"], info["id"], image_id, 
                                       dataset_val.image_reference(image_id)))

# ground truth
visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset_train.class_names, figsize=(8, 8))   ######## dataset_train.class_names

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)
# Out:
# image ID: apple.20130320T013320.053107_44.png (96) /content/drive/My Drive/Mask_RCNN/datasets/apples/val/20130320T013320.053107_44.png
# original_image           shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# image_meta               shape: (14,)                 min:    0.00000  max: 1024.00000  float64
# gt_class_id              shape: (7,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (7, 4)                min:    0.00000  max:  846.00000  int32
# gt_mask                  shape: (1024, 1024, 7)       min:    0.00000  max:    1.00000  bool

# %%
# Run object detection
results = model.detect([original_image], verbose=1)

# Display results
ax = get_ax(1)
r = results[0]
visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                            dataset_val.class_names, r['scores'], ax=ax,
                            title="Predictions")
# Out:
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  int64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32

# %% [markdown]
# ## Evaluation

# %%
# Compute VOC-Style mAP @ IoU=0.5
# Running on 10 images. Increase for better accuracy.
image_ids = np.random.choice(dataset_val.image_ids, 10)
print(image_ids)
APs = []
for image_id in image_ids:
    # Load image and ground truth data
    image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_val, inference_config,
                               image_id, use_mini_mask=False)   ###### from the validation set
    molded_images = np.expand_dims(modellib.mold_image(image, inference_config), 0)
    # Run object detection
    results = model.detect([image], verbose=0)
    r = results[0]
    # Compute AP
    AP, precisions, recalls, overlaps =\
        utils.compute_ap(gt_bbox, gt_class_id, gt_mask,
                         r["rois"], r["class_ids"], r["scores"], r['masks'])
    APs.append(AP)
    
print("mAP: ", np.mean(APs))
# Out:
# mAP:  0.4961832672357559

# %%
# Draw precision-recall curve
AP, precisions, recalls, overlaps = utils.compute_ap(gt_bbox, gt_class_id, gt_mask,
                                          r['rois'], r['class_ids'], r['scores'], r['masks'])
visualize.plot_precision_recall(AP, precisions, recalls)

# %%
# Grid of ground truth objects and their predictions
visualize.plot_overlaps(gt_class_id, r['class_ids'], r['scores'],
                        overlaps, dataset_val.class_names)
